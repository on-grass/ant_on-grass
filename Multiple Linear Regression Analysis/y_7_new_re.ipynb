# %%
import pandas as pd
import numpy as np

import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

matplotlib.rcParams['font.family']='Malgun Gothic'
matplotlib.rcParams['axes.unicode_minus']=False

from sklearn.preprocessing import StandardScaler  # 표준화 패키지 라이브러리 
import statsmodels.api as sm

# %%
### 시도 데이터
# df_5_,df_6_1~df_12_1 ,result_2

### 시군구 파일
# df_5,df_6_~df_12_

df_5_=pd.read_csv('시도_df_5_.csv',encoding='cp949')
df_6_1=pd.read_csv('시도_df_6_1.csv',encoding='cp949')
df_7_1=pd.read_csv('시도_df_7_1.csv',encoding='cp949')
df_8_1=pd.read_csv('시도_df_8_1.csv',encoding='cp949')
df_9_1=pd.read_csv('시도_df_9_1.csv',encoding='cp949')
df_10_1=pd.read_csv('시도_ddf_10_1.csv',encoding='cp949')
df_11_1=pd.read_csv('시도_df_11_1.csv',encoding='cp949')
df_12_1=pd.read_csv('시도_df_12_1.csv',encoding='cp949')
result_2=pd.read_csv('시도_result_2.csv',encoding='cp949')


df_5=pd.read_csv('시군구_df_5.csv',encoding='cp949')
df_6_=pd.read_csv('시군구_df_6_.csv',encoding='cp949')
df_7_=pd.read_csv('시군구_df_7_.csv',encoding='cp949')
df_8_=pd.read_csv('시군구_df_8_.csv',encoding='cp949')
df_9_=pd.read_csv('시군구_df_9_.csv',encoding='cp949')
df_10_=pd.read_csv('시군구_df_10_.csv',encoding='cp949')
df_11_=pd.read_csv('시군구_df_11_.csv',encoding='cp949')
df_12_=pd.read_csv('시군구_df_12_.csv',encoding='cp949')


result6_1= pd.merge(df_5_,df_6_1,how='outer',on='시도')
result7_1= pd.merge(df_5_,df_7_1,how='outer',on='시도')
result8_1= pd.merge(df_5_,df_8_1,how='outer',on='시도')
result9_1= pd.merge(df_5_,df_9_1,how='outer',on='시도')
result10_1= pd.merge(df_5_,df_10_1,how='outer',on='시도')
result11_1= pd.merge(df_5_,df_11_1,how='outer',on='시도')
result12_1= pd.merge(df_5_,df_12_1,how='outer',on='시도')
result2_1= pd.merge(df_5_,result_2,how='outer',on='시도')

result6_= pd.merge(df_5,df_6_,how='outer',on='시군구')
result7_= pd.merge(df_5,df_7_,how='outer',on='시군구')
result8_= pd.merge(df_5,df_8_,how='outer',on='시군구')
result9_= pd.merge(df_5,df_9_,how='outer',on='시군구')
result10_= pd.merge(df_5,df_10_,how='outer',on='시군구')
result11_= pd.merge(df_5,df_11_,how='outer',on='시군구')
result12_= pd.merge(df_5,df_12_,how='outer',on='시군구')


## 불러오기로 인해 인덱스 픽쳐가 생김 지우기

result6_1=result6_1.drop(columns={'Unnamed: 0_x','Unnamed: 0_y'},axis=1)
result7_1=result7_1.drop(columns={'Unnamed: 0_x','Unnamed: 0_y'},axis=1)
result8_1=result8_1.drop(columns={'Unnamed: 0_x','Unnamed: 0_y'},axis=1)
result9_1=result9_1.drop(columns={'Unnamed: 0_x','Unnamed: 0_y'},axis=1)
result10_1=result10_1.drop(columns={'Unnamed: 0_x','Unnamed: 0_y'},axis=1)
result11_1=result11_1.drop(columns={'Unnamed: 0_x','Unnamed: 0_y'},axis=1)
result12_1=result12_1.drop(columns={'Unnamed: 0_x','Unnamed: 0_y'},axis=1)
result2_1=result2_1.drop(columns={'Unnamed: 0_x','Unnamed: 0_y'},axis=1)

result6_=result6_.drop(columns={'Unnamed: 0_x','Unnamed: 0_y','시도_y'},axis=1)
result7_=result7_.drop(columns={'Unnamed: 0_x','Unnamed: 0_y','시도_y'},axis=1)
result8_=result8_.drop(columns={'Unnamed: 0_x','Unnamed: 0_y','시도_y'},axis=1)
result9_=result9_.drop(columns={'Unnamed: 0_x','Unnamed: 0_y','시도_y'},axis=1)
result10_=result10_.drop(columns={'Unnamed: 0_x','Unnamed: 0_y','시도_y'},axis=1)
result11_=result11_.drop(columns={'Unnamed: 0_x','Unnamed: 0_y','시도_y'},axis=1)
result12_=result12_.drop(columns={'Unnamed: 0_x','Unnamed: 0_y','시도_y'},axis=1)

result6_=result6_.rename({'시도_x':'시도'},axis=1)
result7_=result7_.rename({'시도_x':'시도'},axis=1)
result8_=result8_.rename({'시도_x':'시도'},axis=1)
result9_=result9_.rename({'시도_x':'시도'},axis=1)
result10_=result10_.rename({'시도_x':'시도'},axis=1)
result11_=result11_.rename({'시도_x':'시도'},axis=1)
result12_=result12_.rename({'시도_x':'시도'},axis=1)

# %%
result_sido_x= pd.merge(df_5_,df_6_1,how='outer',on='시도')
result_sido_x= pd.merge(result_sido_x,df_7_1,how='outer',on='시도')
result_sido_x= pd.merge(result_sido_x,df_8_1,how='outer',on='시도')
result_sido_x= pd.merge(result_sido_x,df_9_1,how='outer',on='시도')
result_sido_x= pd.merge(result_sido_x,df_10_1,how='outer',on='시도')
result_sido_x= pd.merge(result_sido_x,df_11_1,how='outer',on='시도')
result_sido_x= pd.merge(result_sido_x,df_12_1,how='outer',on='시도')
result_sido_x= pd.merge(result_sido_x,result_2,how='outer',on='시도')

result_sigungu_x= pd.merge(df_5,df_6_,how='outer',on='시군구')
result_sigungu_x= pd.merge(result_sigungu_x,df_7_,how='outer',on='시군구')
result_sigungu_x= pd.merge(result_sigungu_x,df_8_,how='outer',on='시군구')
result_sigungu_x= pd.merge(result_sigungu_x,df_9_,how='outer',on='시군구')
result_sigungu_x= pd.merge(result_sigungu_x,df_10_,how='outer',on='시군구')
result_sigungu_x= pd.merge(result_sigungu_x,df_11_,how='outer',on='시군구')
result_sigungu_x= pd.merge(result_sigungu_x,df_12_,how='outer',on='시군구')
# Out:
# C:\Users\user\anaconda3\envs\env_3.7\lib\site-packages\ipykernel_launcher.py:3: FutureWarning: Passing 'suffixes' which cause duplicate columns {'Unnamed: 0_x'} in the result is deprecated and will raise a MergeError in a future version.
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\user\anaconda3\envs\env_3.7\lib\site-packages\ipykernel_launcher.py:5: FutureWarning: Passing 'suffixes' which cause duplicate columns {'Unnamed: 0_x'} in the result is deprecated and will raise a MergeError in a future version.
#   """
# C:\Users\user\anaconda3\envs\env_3.7\lib\site-packages\ipykernel_launcher.py:7: FutureWarning: Passing 'suffixes' which cause duplicate columns {'Unnamed: 0_x'} in the result is deprecated and will raise a MergeError in a future version.
#   import sys
# ...

# %%
#확인

# %%
cor_a_y_rule_total_=['가정용 물사용량(세제곱미터_일)_비시가_하수처리지역_분류식',
 '비시가 인구(명)_하수처리지역(분류식)',
 '위탁 처리_업소수(개)',
 '총계_폐수발생량(세제곱미터_일)',
 '산업_총계_업소수(개)',
 '위탁 처리_TP발생부하량(킬로그램_일)',
 '공장용지',
 '직접 방류_업소수(개)',
 '영업용 물사용량(세제곱미터_일)_비시가_하수처리지역_분류식',
 '영업용 물사용량(세제곱미터_일)_비시가_하수미처리지역_오수',
 '하천',
 '시가 인구(명)_하수미처리지역(오수)',
 '가정용 물사용량(세제곱미터_일)_시가_하수미처리지역_오수',
 '가정용 물사용량(세제곱미터_일)_비시가_하수미처리지역_오수',
 '비시가 인구(명)_하수미처리지역(오수)',
 '가정용 물사용량(세제곱미터_일)_시가_하수처리지역_분류식',
 '시가 인구(명)_하수처리지역(분류식)',
 '운수장비정비시설(폐차장포함)',
 '영업용 물사용량(세제곱미터_일)_시가_하수처리지역_분류식',
 '시가 인구(명)_하수미처리지역(정화조)',
 '가정용 물사용량(세제곱미터_일)_시가_하수미처리지역_정화조',
 '직접 방류_TP배출부하량(킬로그램_일)',
 '영업용 물사용량(세제곱미터_일)_시가_하수미처리지역_오수',
 '목장용지',
 '총계_TP배출부하량(킬로그램_일)',
 '영업용 물사용량(세제곱미터_일)_비시가_하수미처리지역_정화조',
 '사육두수(두)',
 '가축분뇨발생량(세제곱미터_일)',
 '가정용 물사용량(세제곱미터_일)_비시가_하수미처리지역_정화조',
 '자가처리_퇴비화(세제곱미터_일)',
 '비시가 인구(명)_하수미처리지역(정화조)',
 '위탁처리_공공처리시설(세제곱미터_일)']

#  '지수식_업소수(개)'   << 추가 목록

# %%
## 추가 목록


a_sub_b=['지수식_업소수(개)',
 '지수식_사료사용량(킬로그램_월)',
 '종말처리장 연계_업소수(개)',
 '종말처리장 연계_TP배출부하량(킬로그램_일)',
 '종말처리장 연계_SS배출부하량(킬로그램_일)',
 '종말처리장 연계_BOD배출부하량(킬로그램_일)',
 '전',
 '자가처리_정화방류(세제곱미터_일)',
 '자가처리_액비화(세제곱미터_일)',
 '인구 총계(명)',
 '위탁처리_재활용신고자(세제곱미터_일)',
 '영업용 물사용량(세제곱미터_일)_합계',
 '영업용 물사용량(세제곱미터_일)_시가_하수처리지역_합류식',
 '영업용 물사용량(세제곱미터_일)_시가_하수미처리지역_정화조',
 '시가 인구(명)_하수처리지역(합류식)',
 '시가 인구(명)_하수미처리지역(수거식)',
 '사진처리 또는 X-Ray 시설',
 '비시가 인구(명)_하수미처리지역(수거식)',
 '미처리(세제곱미터_일)',
 '도전양식_업소수(개)',
 '농축수산물 단순가공시설',
 '농가수(호)',
 '기타_총계(개소)',
 '과수원',
 '가정용 물사용량(세제곱미터_일)_합계',
 '가정용 물사용량(세제곱미터_일)_시가_하수처리지역_합류식',
 '가정용 물사용량(세제곱미터_일)_시가_하수미처리지역_수거식',
 '가정용 물사용량(세제곱미터_일)_비시가_하수처리지역_합류식',
 '가정용 물사용량(세제곱미터_일)_비시가_하수미처리지역_수거식',
 '가두리_업소수(개)',
 '가두리_시설 면적(제곱미터)',
 '가두리_사료사용량(킬로그램_월)']


#a_sub_b = [x for x in cor_a_y_rule_total_xxx if x not in cor_a_y_rule_total_]
#a_sub_b.sort(reverse=True)
#a_sub_b

# %%
col_list=cor_a_y_rule_total_+a_sub_b

# %%
result_sigungu_x_test=result_sigungu_x.copy()
result_sigungu_x_test_x=result_sigungu_x.copy()

result_sigungu_x_test=result_sigungu_x_test.dropna()
result_sigungu_x_test=result_sigungu_x_test.loc[:,col_list]

result_sigungu_x_test['시군구']=result_sigungu_x.iloc[:,2]
result_sigungu_x_test['시도']=result_sigungu_x.iloc[:,1]
result_sigungu_x_test['유형별횟수']=result_sigungu_x.iloc[:,9]
#result_sigungu_x_test.head(0)


result_sigungu_x_test=result_sigungu_x_test.reset_index()

X=result_sigungu_x_test.iloc[:,1:-3] #수정해야함

scale_X_test = StandardScaler().fit_transform(X)
scale_X_test = pd.DataFrame(scale_X_test)
scale_X_test.columns = result_sigungu_x_test.iloc[:,1:-3].columns
#scale_X_test=scale_X_test.iloc[:,1:]

# %%
a=np.zeros(len(result_sigungu_x_test))
result_sigungu_x_test['y_7']=a

for i in range(len(result_sigungu_x_test)):
    a=[]
    a=scale_X_test['목장용지'][i]*scale_X_test['사육두수(두)'][i]*scale_X_test['가축분뇨발생량(세제곱미터_일)'][i]/scale_X_test['자가처리_퇴비화(세제곱미터_일)'][i]*scale_X_test['하천'][i]
    
    result_sigungu_x_test['y_7'][i] = a

y_7=result_sigungu_x_test[['시군구','y_7']]
# Out:
# C:\Users\user\anaconda3\envs\env_3.7\lib\site-packages\ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
from sklearn.model_selection import train_test_split

X_train,X_test,y_train_1,y_test_1=train_test_split(scale_X_test,y_7,test_size=0.15,shuffle=False,random_state=1000)

# %%
y_train_sigungu_1=y_train_1.copy()

# %%
y_train_1=y_train_1['y_7']

# %%
import statsmodels.api as sm
results_1 = sm.OLS(y_train_1, sm.add_constant(X_train)).fit()
results_1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                    y_7   R-squared:                       0.913
# Model:                            OLS   Adj. R-squared:                  0.828
# Method:                 Least Squares   F-statistic:                     10.81
# Date:                Thu, 16 Feb 2023   Prob (F-statistic):           7.11e-18
# Time:                        10:55:30   Log-Likelihood:                 3.2296
# No. Observations:                 125   AIC:                             117.5
# Df Residuals:                      63   BIC:                             292.9
# Df Model:                          61
# Covariance Type:            nonrobust
# ...
#                                         coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------
# ...

# %%
# 다 지우기_1


results_1_y_1_pvalues=results_1.pvalues
df_pvalues=pd.DataFrame(results_1_y_1_pvalues)
df_pvalues=df_pvalues.sort_values(0)
a=list(df_pvalues[(df_pvalues[0] >= 0.35) | (df_pvalues[0] <= -0.2)].sort_values(0,ascending = False).index)

col_list_sub_all_1 = [x for x in col_list if x not in a]
col_list_sub_all_1.sort(reverse=True)
col_list_sub_all_1


result_sigungu_x_test=result_sigungu_x.copy()
result_sigungu_x_test_x=result_sigungu_x.copy()

result_sigungu_x_test=result_sigungu_x_test.dropna()
result_sigungu_x_test=result_sigungu_x_test.loc[:,col_list_sub_all_1]

result_sigungu_x_test['시군구']=result_sigungu_x.iloc[:,2]
result_sigungu_x_test['시도']=result_sigungu_x.iloc[:,1]
result_sigungu_x_test['유형별횟수']=result_sigungu_x.iloc[:,9]

result_sigungu_x_test=result_sigungu_x_test.reset_index()

X=result_sigungu_x_test.iloc[:,1:-3] #수정해야함

scale_X_y_1_sub_all = StandardScaler().fit_transform(X)
scale_X_y_1_sub_all = pd.DataFrame(scale_X_y_1_sub_all)
scale_X_y_1_sub_all.columns = result_sigungu_x_test.iloc[:,1:-3].columns


from sklearn.model_selection import train_test_split

scale_X_y_1_sub_all,X_test_y_1_sub_all,y_train_1,y_test_1=train_test_split(scale_X_y_1_sub_all,y_7,test_size=0.15,shuffle=False,random_state=1000)

y_train_sigungu_1=y_train_1.copy()

y_train_1=y_train_1['y_7']

import statsmodels.api as sm
results_1_sub_all = sm.OLS(y_train_1, sm.add_constant(scale_X_y_1_sub_all)).fit()
results_1_sub_all.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                    y_7   R-squared:                       0.852
# Model:                            OLS   Adj. R-squared:                  0.810
# Method:                 Least Squares   F-statistic:                     20.61
# Date:                Thu, 16 Feb 2023   Prob (F-statistic):           3.18e-29
# Time:                        10:55:30   Log-Likelihood:                -30.027
# No. Observations:                 125   AIC:                             116.1
# Df Residuals:                      97   BIC:                             195.2
# Df Model:                          27
# Covariance Type:            nonrobust
# ...
#                                         coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------
# ...

# %%
# 다 지우기_2

results_1_sub_all_pvalues=results_1_sub_all.pvalues
df_pvalues=pd.DataFrame(results_1_sub_all_pvalues)
df_pvalues=df_pvalues.sort_values(0)
a_2=list(df_pvalues[(df_pvalues[0] >= 0.2) | (df_pvalues[0] <= -0.2)].sort_values(0,ascending = False).index)


col_list_sub_all_2 = [x for x in col_list_sub_all_1 if x not in a_2]
col_list_sub_all_2.sort(reverse=True)
col_list_sub_all_2


result_sigungu_x_test=result_sigungu_x.copy()
result_sigungu_x_test_x=result_sigungu_x.copy()

result_sigungu_x_test=result_sigungu_x_test.dropna()
result_sigungu_x_test=result_sigungu_x_test.loc[:,col_list_sub_all_2]

result_sigungu_x_test['시군구']=result_sigungu_x.iloc[:,2]
result_sigungu_x_test['시도']=result_sigungu_x.iloc[:,1]
result_sigungu_x_test['유형별횟수']=result_sigungu_x.iloc[:,9]


result_sigungu_x_test=result_sigungu_x_test.reset_index()

X=result_sigungu_x_test.iloc[:,1:-3] #수정해야함

scale_X_y_1_sub_all_2 = StandardScaler().fit_transform(X)
scale_X_y_1_sub_all_2 = pd.DataFrame(scale_X_y_1_sub_all_2)
scale_X_y_1_sub_all_2.columns = result_sigungu_x_test.iloc[:,1:-3].columns


from sklearn.model_selection import train_test_split

X_train_y_1_sub_all_2,X_test_y_1_sub_all_2,y_train_1,y_test_1=train_test_split(scale_X_y_1_sub_all_2,y_7,test_size=0.15,shuffle=False,random_state=1000)

y_train_sigungu_1=y_train_1.copy()

y_train_1=y_train_1['y_7']

import statsmodels.api as sm
results_1_sub_all_2 = sm.OLS(y_train_1, sm.add_constant(X_train_y_1_sub_all_2)).fit()
results_1_sub_all_2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                    y_7   R-squared:                       0.843
# Model:                            OLS   Adj. R-squared:                  0.823
# Method:                 Least Squares   F-statistic:                     42.09
# Date:                Thu, 16 Feb 2023   Prob (F-statistic):           1.35e-37
# Time:                        10:55:30   Log-Likelihood:                -33.654
# No. Observations:                 125   AIC:                             97.31
# Df Residuals:                     110   BIC:                             139.7
# Df Model:                          14
# Covariance Type:            nonrobust
# ...
#                                         coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------
# ...

# %%
print(len(X_test_y_1_sub_all_2))
len(X_test_y_1_sub_all_2.columns)
# Out:
# 23
# 14

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

vif =pd.DataFrame()
vif['vif_factor'] =[variance_inflation_factor(scale_X_y_1_sub_all_2.values,i) for i in range(scale_X_y_1_sub_all_2.shape[1])]
vif['feature'] =scale_X_y_1_sub_all_2.columns
vif=vif.dropna(axis=0)
vif =vif.sort_values('vif_factor').reset_index(drop=True)
#vif_=vif.dropna(axis=0)
#a=list(vif_.iloc[:-3]['feature'])
vif
# Out:
#     vif_factor                            feature
# 0     1.290428                                 하천
# 1     1.350238                    가두리_시설 면적(제곱미터)
# 2     1.678381  가정용 물사용량(세제곱미터_일)_비시가_하수미처리지역_정화조
# 3     2.036998                  가두리_사료사용량(킬로그램_월)
# 4     2.954822                                과수원
# 5     4.801460    영업용 물사용량(세제곱미터_일)_시가_하수미처리지역_오수
# 6     5.941086                               목장용지
# 7    12.541711   영업용 물사용량(세제곱미터_일)_비시가_하수처리지역_분류식
# 8    14.244310  영업용 물사용량(세제곱미터_일)_비시가_하수미처리지역_정화조
# 9    20.748647   영업용 물사용량(세제곱미터_일)_비시가_하수미처리지역_오수
# 10   28.124684   영업용 물사용량(세제곱미터_일)_시가_하수미처리지역_정화조
# 11   61.409395    영업용 물사용량(세제곱미터_일)_시가_하수처리지역_분류식
# 12   62.982986    영업용 물사용량(세제곱미터_일)_시가_하수처리지역_합류식
# 13  374.441406               영업용 물사용량(세제곱미터_일)_합계

# %%
sm.graphics.plot_leverage_resid2(results_1_sub_all_2)
plt.show()

# %%
X_train_del = X_train_y_1_sub_all_2.drop([80,12])
y_train_1_del=y_train_1.drop([80,12])

# %%
import statsmodels.api as sm
results_1_sub_all_2_del = sm.OLS(y_train_1_del, sm.add_constant(X_train_del)).fit()
results_1_sub_all_2_del.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                    y_7   R-squared:                       0.886
# Model:                            OLS   Adj. R-squared:                  0.871
# Method:                 Least Squares   F-statistic:                     60.03
# Date:                Thu, 16 Feb 2023   Prob (F-statistic):           2.74e-44
# Time:                        10:55:55   Log-Likelihood:                -11.900
# No. Observations:                 123   AIC:                             53.80
# Df Residuals:                     108   BIC:                             95.98
# Df Model:                          14
# Covariance Type:            nonrobust
# ...
#                                         coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------
# ...

# %%
sm.graphics.plot_leverage_resid2(results_1_sub_all_2_del)
plt.show()

# %%
X_train_del_2 = X_train_del.drop([16,0])
y_train_1_del_2=y_train_1_del.drop([16,0])

# %%
print(len(X_train_del_2))
len(X_train_del_2.columns)
# Out:
# 121
# 14

# %%
import statsmodels.api as sm
results_1_sub_all_2_del_2 = sm.OLS(y_train_1_del_2, sm.add_constant(X_train_del_2)).fit()
results_1_sub_all_2_del_2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                    y_7   R-squared:                       0.897
# Model:                            OLS   Adj. R-squared:                  0.883
# Method:                 Least Squares   F-statistic:                     65.89
# Date:                Thu, 16 Feb 2023   Prob (F-statistic):           1.18e-45
# Time:                        10:56:00   Log-Likelihood:                -6.6356
# No. Observations:                 121   AIC:                             43.27
# Df Residuals:                     106   BIC:                             85.21
# Df Model:                          14
# Covariance Type:            nonrobust
# ...
#                                         coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------
# ...

# %%
sm.graphics.plot_leverage_resid2(results_1_sub_all_2_del_2)
plt.show()

# %%
# 

import scipy as sp 

figure, axs = plt.subplots(1, 3, figsize = (15, 6))

# 잔차 Q-Q plot
sp.stats.probplot(results_1_sub_all_2_del_2.resid, dist = 'norm', fit = True, plot = axs[0])

# 잔차의 histogram
sns.distplot(x = results_1_sub_all_2_del_2.resid, ax = axs[1])
axs[1].set_xlabel('Residuals')
axs[1].set_title('residuals histogram')


# 잔차도
yhat = results_1_sub_all_2_del_2.fittedvalues
temp = pd.concat([yhat, y_train_1_del_2], axis = 1)
temp.columns = ["yhat", "y"]

sns.residplot(x = "yhat", y = "y", data = temp, ax = axs[2])

MSE_sq = np.sqrt(results_1_sub_all_2_del_2.mse_resid)

# 잔차도 MSE line
for i, c in enumerate(["red", "green", "black"]):
    axs[2].axhline( (i+1) * MSE_sq, color = c)
    axs[2].axhline( -(i+1) * MSE_sq, color = c)
    
    axs[2].text(47, (i+1) * MSE_sq, f"{i+1}"r'${}\sqrt{MSE}$')
    axs[2].text(47, -(i+1) * MSE_sq, f"-{i+1}"r'${}\sqrt{MSE}$')

axs[2].set_xlabel("Fitted Values")
axs[2].set_ylabel("Standardized Residuals")
axs[2].set_title("Residuals Diagram")


fig = plt.figure(figsize= (10,8))

p = sns.residplot(x = "yhat", y = "y", 
                  data = temp)

p.set_title("Residuals Diagram", fontsize=15, y=1.02)
p.set(xlabel= "Fitted Values", ylabel = "Residuals")

plt.show()
# Out:
# C:\Users\user\anaconda3\envs\env_3.7\lib\site-packages\ipykernel_launcher.py:11: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   # This is added back by InteractiveShellApp.init_path()

# %%
from statsmodels.stats.stattools import durbin_watson

print(f"D-W 통계량: {round(durbin_watson(results_1_sub_all_2_del_2.resid),3)}")
# Out:
# D-W 통계량: 2.122

# %%
ypred = results_1_sub_all_2_del_2.predict(sm.add_constant(scale_X_y_1_sub_all_2))
ypred_=list(np.round(ypred, 5))

# %%
nm=list(result_sigungu_x_test['시군구'])

# %%
df_pred=pd.DataFrame({'nm':nm,'y_pred':ypred})
df_pred=df_pred.sort_values('y_pred',ascending=False).reset_index()
end_list=list(df_pred.iloc[0:20]['nm'])

# %%
end_list=['남동구','영천시','청송군','의성군','충주시','안동시','파주시','김천시','나주시','양평군','밀양시','군위군','청도군','인천서구','포천시','영주시','울진군','공주시','봉화군','군산시']

# %%
sido_nm=['인천광역시','경상북도','경상북도','경상북도','충청북도','경상북도','경기도','경상북도','전라남도','경기도','경상남도','경상북도','경상북도','인천광역시','경기도','경상북도','경상북도','충청남도','경상북도','전라북도']
